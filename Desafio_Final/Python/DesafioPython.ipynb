# %% [markdown]
# # Desafio Final Python

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/dados_rh.csv')

# %% [markdown]
# # Característica do Banco de Dados

# %%
# a) Quantidade de (Linhas, Colunas) no banco de dados
df.shape
# Out:
# (1470, 35)

# %%
# b) Dados nulos/ Número de Dados Nulos
df.isnull()
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# c) Tipos de Dados
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# # Agrupamento de Dados e Plotagem de Gráficos

# %%
soma_coluna = df['EmployeeNumber'].sum()

# %%
# a)Plote um gráfico de barras (bar) que exiba a quantidade de funcionários em cada setor (coluna Department);

department_counts = df['Department'].value_counts().sort_index()


plt.figure(figsize=(10,6))
plt.bar(education_counts.index, education_counts.values)
plt.title('Quantidade de Funcionário para cada Setor')
plt.xlabel('Setor')
plt.ylabel('Número de Funcionários')
# Out:
# Text(0, 0.5, 'Número de Funcionários')

# %%
# b) Plote um gráfico de linha (line) que exiba a quantidade de funcionários para cada nível de escolaridade (coluna Education);

education_counts = df['Education'].value_counts().sort_index()


plt.figure(figsize=(10,6))
plt.plot(education_counts.index, education_counts.values, marker='o')
plt.title('Quantidade de funcionários para cada nível de escolaridade')
# Out:
# Text(0.5, 1.0, 'Quantidade de funcionários para cada nível de escolaridade')

# %%
# c) Plote um gráfico de torta/pizza (pie) que exiba a quantidade de funcionários que tem ou não algum atrito na empresa (coluna Attrition).

attrition_counts = df['Attrition'].value_counts().sort_index()


plt.figure(figsize=(8, 8))
plt.pie(attrition_counts.values, labels=attrition_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Porcentagem de Atritos com a empresa')
plt.axis('equal')  # Garante que o gráfico seja desenhado como um círculo
plt.tight_layout()
plt.show()
